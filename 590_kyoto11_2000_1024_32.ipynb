# %% [markdown]
# # file name meaning
#
# eg. 100_cairo_2000_1024_32.ipynb
#
# `[tag]_[dataset_name]_[epochs/maxIters]_[data_length/seq_len]_[batch_size]`

# %%
from train_network_synthetic import train_ttn

from configuration import general
import os
from configuration.configure import JUPYTER_TOKEN


nb_name_file = general.ipy_nb_name(JUPYTER_TOKEN["token_lists"])
# Out:
# /home/musk/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/musk/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/musk/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/musk/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/musk/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/musk/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
theNotebook = nb_name_file.split('_')
assert len(theNotebook) == 5, 'The number of parameters should be 5'

global title_param
title_param = {
    'num': theNotebook[0],
    'dataset_name': theNotebook[1],
    'maxIters': int(theNotebook[2]),
    'seq_len': int(theNotebook[3]),
    'batch_size': int(theNotebook[4]),
}

# assert title_param['dataset'] in ['cairo', 'milan', 'kyoto7', 'kyoto8', 'kyoto11'], 'Please correct the dataset name！'
# assert title_param['model_name'] in ['WCNN','LSTM'], 'The method is wrong. Please correct it！'
# assert title_param['optimizer'] in ['rms', 'adagrad'], 'The optimizer is wrong. Please correct it！'
# assert title_param['calculation_unit'] in ['0', '1', '2'], 'Error in calculation unit selection, please correct！'

display(title_param)
# Out:
# {'num': '590',
#  'dataset_name': 'kyoto11',
#  'maxIters': 2000,
#  'seq_len': 1024,
#  'batch_size': 32}

# %%
dict_cus = {
    "dataset_name": "",
    "maxIters": "",  # 100000
    "seq_len": "",
    "batch_size": "",
}

dict_cus = general.Merge(dict_cus, title_param)
dict_cus
# Out:
# {'dataset_name': 'kyoto11',
#  'maxIters': 2000,
#  'seq_len': 1024,
#  'batch_size': 32,
#  'num': '590'}

# %%
import tensorflow as tf

calculation_unit = general.getAvailableId()
os.environ["CUDA_VISIBLE_DEVICES"] = calculation_unit

if calculation_unit != "-1":
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    session = tf.Session(config=config)

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# GPU used: [66, 50], final choose: 1

# %% [markdown]
# [origin](#origin)
#
# [C](#constrain)
#
# [CS_1](#constrain_1)
#
# [CS_2](#constrain_2)
#
# [CS_3](#constrain_3)
#
# [CS_4](#constrain_4)
#
# [CS_5](#constrain_5)
#
# [statics](#statics)

# %% [markdown]
# # <a id='origin'>origin</a>

# %%
# %%time
dict_cus["distance_int"] = 9999
train_ttn(dict_cus)
# Out:
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# WARNING:tensorflow:From /home/musk/project/paperEdit/haredit-ttn/network_ttn_synthetic.py:31: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/musk/project/paperEdit/haredit-ttn/network_ttn_synthetic.py:32: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/musk/project/paperEdit/haredit-ttn/network_ttn_synthetic.py:78: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /home/musk/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:189: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# k: 0	step: 0/212000, loss_value: 2.3968944549560547
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_0_gaussians_github_ttn_2.3968945
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_0_gaussians_github_ttn_2.3968945
# Accuracy: 0.1404330017554125
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.15096547688706846
#
#
# k: 0	step: 1000/212000, loss_value: 1.6665875911712646
# k: 0	step: 2000/212000, loss_value: 1.540738582611084
# k: 0	step: 3000/212000, loss_value: 1.6351017951965332
# k: 0	step: 4000/212000, loss_value: 1.6702911853790283
# k: 0	step: 5000/212000, loss_value: 1.5417282581329346
# k: 0	step: 6000/212000, loss_value: 1.8200597763061523
# k: 0	step: 7000/212000, loss_value: 1.4686455726623535
# k: 0	step: 8000/212000, loss_value: 1.5711115598678589
# k: 0	step: 9000/212000, loss_value: 1.523771047592163
# k: 0	step: 10000/212000, loss_value: 1.4616367816925049
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_10600_gaussians_github_ttn_1.5362345
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_10600_gaussians_github_ttn_1.5362345
# Accuracy: 0.4815681685196021
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.48273844353423057
#
#
# k: 0	step: 11000/212000, loss_value: 1.5185308456420898
# k: 0	step: 12000/212000, loss_value: 1.5639770030975342
# k: 0	step: 13000/212000, loss_value: 1.6172199249267578
# k: 0	step: 14000/212000, loss_value: 1.373908281326294
# k: 0	step: 15000/212000, loss_value: 1.0333669185638428
# k: 0	step: 16000/212000, loss_value: 1.2174314260482788
# k: 0	step: 17000/212000, loss_value: 1.403329610824585
# k: 0	step: 18000/212000, loss_value: 1.3911515474319458
# k: 0	step: 19000/212000, loss_value: 1.258746862411499
# k: 0	step: 20000/212000, loss_value: 1.2014437913894653
# k: 0	step: 21000/212000, loss_value: 1.0655674934387207
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_21200_gaussians_github_ttn_1.4605527
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_21200_gaussians_github_ttn_1.4605527
# Accuracy: 0.483908718548859
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.48566413107080164
#
#
# k: 0	step: 22000/212000, loss_value: 1.7987743616104126
# k: 0	step: 23000/212000, loss_value: 1.1203348636627197
# k: 0	step: 24000/212000, loss_value: 1.4184813499450684
# k: 0	step: 25000/212000, loss_value: 1.5252608060836792
# k: 0	step: 26000/212000, loss_value: 1.1187968254089355
# k: 0	step: 27000/212000, loss_value: 1.5994670391082764
# k: 0	step: 28000/212000, loss_value: 1.3395962715148926
# k: 0	step: 29000/212000, loss_value: 1.5839970111846924
# k: 0	step: 30000/212000, loss_value: 1.6745972633361816
# k: 0	step: 31000/212000, loss_value: 1.3222378492355347
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_31800_gaussians_github_ttn_1.1632764
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_31800_gaussians_github_ttn_1.1632764
# Accuracy: 0.4844938560561732
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.4903452311293154
#
#
# k: 0	step: 32000/212000, loss_value: 1.2002294063568115
# k: 0	step: 33000/212000, loss_value: 1.0261679887771606
# k: 0	step: 34000/212000, loss_value: 1.2280917167663574
# k: 0	step: 35000/212000, loss_value: 1.6538500785827637
# k: 0	step: 36000/212000, loss_value: 1.2731026411056519
# k: 0	step: 37000/212000, loss_value: 1.1987950801849365
# k: 0	step: 38000/212000, loss_value: 1.5163657665252686
# k: 0	step: 39000/212000, loss_value: 1.2533771991729736
# k: 0	step: 40000/212000, loss_value: 1.914239525794983
# k: 0	step: 41000/212000, loss_value: 1.4533151388168335
# k: 0	step: 42000/212000, loss_value: 1.1701836585998535
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_42400_gaussians_github_ttn_1.6762289
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_42400_gaussians_github_ttn_1.6762289
# Accuracy: 0.48332358104154477
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.4885898186073727
#
#
# k: 0	step: 43000/212000, loss_value: 1.4585800170898438
# k: 0	step: 44000/212000, loss_value: 1.2124912738800049
# k: 0	step: 45000/212000, loss_value: 1.4458634853363037
# k: 0	step: 46000/212000, loss_value: 1.2217586040496826
# k: 0	step: 47000/212000, loss_value: 1.2992827892303467
# k: 0	step: 48000/212000, loss_value: 1.1802743673324585
# k: 0	step: 49000/212000, loss_value: 1.3236116170883179
# k: 0	step: 50000/212000, loss_value: 1.246742606163025
# k: 0	step: 51000/212000, loss_value: 1.2899048328399658
# k: 0	step: 52000/212000, loss_value: 1.296759009361267
# k: 0	step: 53000/212000, loss_value: 1.3679537773132324
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_53000_gaussians_github_ttn_1.3679538
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_53000_gaussians_github_ttn_1.3679538
# Accuracy: 0.4967817437097718
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.49210064365125805
#
#
# k: 0	step: 54000/212000, loss_value: 1.410876989364624
# k: 0	step: 55000/212000, loss_value: 1.310272455215454
# k: 0	step: 56000/212000, loss_value: 1.2648080587387085
# k: 0	step: 57000/212000, loss_value: 1.4934953451156616
# k: 0	step: 58000/212000, loss_value: 1.6941404342651367
# k: 0	step: 59000/212000, loss_value: 1.2074155807495117
# k: 0	step: 60000/212000, loss_value: 1.407690167427063
# k: 0	step: 61000/212000, loss_value: 1.3293629884719849
# k: 0	step: 62000/212000, loss_value: 1.3642597198486328
# k: 0	step: 63000/212000, loss_value: 1.4732985496520996
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_63600_gaussians_github_ttn_1.598324
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_63600_gaussians_github_ttn_1.598324
# Accuracy: 0.5002925687536571
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.49795201872440026
#
#
# k: 0	step: 64000/212000, loss_value: 1.2337114810943604
# k: 0	step: 65000/212000, loss_value: 1.1457786560058594
# k: 0	step: 66000/212000, loss_value: 1.4409021139144897
# k: 0	step: 67000/212000, loss_value: 1.553688645362854
# k: 0	step: 68000/212000, loss_value: 1.5288803577423096
# k: 0	step: 69000/212000, loss_value: 0.9063912034034729
# k: 0	step: 70000/212000, loss_value: 1.509335994720459
# k: 0	step: 71000/212000, loss_value: 1.1864486932754517
# k: 0	step: 72000/212000, loss_value: 1.2232410907745361
# k: 0	step: 73000/212000, loss_value: 1.1788520812988281
# k: 0	step: 74000/212000, loss_value: 1.583310604095459
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_74200_gaussians_github_ttn_1.3228018
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_74200_gaussians_github_ttn_1.3228018
# Accuracy: 0.49268578115857226
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.49970743124634287
#
#
# k: 0	step: 75000/212000, loss_value: 1.3303618431091309
# k: 0	step: 76000/212000, loss_value: 1.4757651090621948
# k: 0	step: 77000/212000, loss_value: 1.2494633197784424
# k: 0	step: 78000/212000, loss_value: 1.1883879899978638
# k: 0	step: 79000/212000, loss_value: 1.2300946712493896
# k: 0	step: 80000/212000, loss_value: 1.4400503635406494
# k: 0	step: 81000/212000, loss_value: 1.2677018642425537
# k: 0	step: 82000/212000, loss_value: 1.7473773956298828
# k: 0	step: 83000/212000, loss_value: 1.2811282873153687
# k: 0	step: 84000/212000, loss_value: 1.321314811706543
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_84800_gaussians_github_ttn_1.0880535
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_84800_gaussians_github_ttn_1.0880535
# Accuracy: 0.5020479812755998
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.5008777062609713
#
#
# k: 0	step: 85000/212000, loss_value: 1.5187100172042847
# k: 0	step: 86000/212000, loss_value: 1.4255491495132446
# k: 0	step: 87000/212000, loss_value: 1.473201870918274
# k: 0	step: 88000/212000, loss_value: 1.4102897644042969
# k: 0	step: 89000/212000, loss_value: 1.3362683057785034
# k: 0	step: 90000/212000, loss_value: 1.30351722240448
# k: 0	step: 91000/212000, loss_value: 1.136713981628418
# k: 0	step: 92000/212000, loss_value: 1.427677869796753
# k: 0	step: 93000/212000, loss_value: 1.4405450820922852
# k: 0	step: 94000/212000, loss_value: 1.251509189605713
# k: 0	step: 95000/212000, loss_value: 1.152293086051941
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_95400_gaussians_github_ttn_1.231915
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_95400_gaussians_github_ttn_1.231915
# Accuracy: 0.49853715623171446
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.49853715623171446
#
#
# k: 0	step: 96000/212000, loss_value: 1.5185909271240234
# k: 0	step: 97000/212000, loss_value: 1.397743582725525
# k: 0	step: 98000/212000, loss_value: 1.3962900638580322
# k: 0	step: 99000/212000, loss_value: 1.350515604019165
# k: 0	step: 100000/212000, loss_value: 1.0830862522125244
# k: 0	step: 101000/212000, loss_value: 1.1332271099090576
# k: 0	step: 102000/212000, loss_value: 1.004809856414795
# k: 0	step: 103000/212000, loss_value: 1.3632616996765137
# k: 0	step: 104000/212000, loss_value: 1.1069700717926025
# k: 0	step: 105000/212000, loss_value: 1.467839241027832
# k: 0	step: 106000/212000, loss_value: 1.1173095703125
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_106000_gaussians_github_ttn_1.1173096
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_106000_gaussians_github_ttn_1.1173096
# Accuracy: 0.49327091866588646
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.49970743124634287
#
#
# k: 0	step: 107000/212000, loss_value: 1.23622465133667
# k: 0	step: 108000/212000, loss_value: 1.436264157295227
# k: 0	step: 109000/212000, loss_value: 1.1482841968536377
# k: 0	step: 110000/212000, loss_value: 1.089942216873169
# k: 0	step: 111000/212000, loss_value: 1.0949959754943848
# k: 0	step: 112000/212000, loss_value: 1.1333173513412476
# k: 0	step: 113000/212000, loss_value: 1.143005132675171
# k: 0	step: 114000/212000, loss_value: 1.440840244293213
# k: 0	step: 115000/212000, loss_value: 1.4832079410552979
# k: 0	step: 116000/212000, loss_value: 1.4767825603485107
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_116600_gaussians_github_ttn_1.2947886
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_116600_gaussians_github_ttn_1.2947886
# Accuracy: 0.49268578115857226
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.49268578115857226
#
#
# k: 0	step: 117000/212000, loss_value: 1.1536765098571777
# k: 0	step: 118000/212000, loss_value: 1.0336203575134277
# k: 0	step: 119000/212000, loss_value: 1.3329479694366455
# k: 0	step: 120000/212000, loss_value: 1.1147733926773071
# k: 0	step: 121000/212000, loss_value: 1.2247252464294434
# k: 0	step: 122000/212000, loss_value: 1.097061038017273
# k: 0	step: 123000/212000, loss_value: 1.4744246006011963
# k: 0	step: 124000/212000, loss_value: 1.2133980989456177
# k: 0	step: 125000/212000, loss_value: 1.268022894859314
# k: 0	step: 126000/212000, loss_value: 1.4268949031829834
# k: 0	step: 127000/212000, loss_value: 1.0838932991027832
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_127200_gaussians_github_ttn_1.0708175
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_127200_gaussians_github_ttn_1.0708175
# Accuracy: 0.4961966062024576
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.48624926857811585
#
#
# k: 0	step: 128000/212000, loss_value: 1.1829168796539307
# k: 0	step: 129000/212000, loss_value: 1.0927526950836182
# k: 0	step: 130000/212000, loss_value: 1.5224494934082031
# k: 0	step: 131000/212000, loss_value: 1.1736273765563965
# k: 0	step: 132000/212000, loss_value: 1.2682387828826904
# k: 0	step: 133000/212000, loss_value: 1.4124115705490112
# k: 0	step: 134000/212000, loss_value: 1.8643872737884521
# k: 0	step: 135000/212000, loss_value: 1.0469332933425903
# k: 0	step: 136000/212000, loss_value: 1.393711805343628
# k: 0	step: 137000/212000, loss_value: 1.4089365005493164
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_137800_gaussians_github_ttn_1.4887197
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_137800_gaussians_github_ttn_1.4887197
# Accuracy: 0.497366881217086
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.49268578115857226
#
#
# k: 0	step: 138000/212000, loss_value: 1.4166141748428345
# k: 0	step: 139000/212000, loss_value: 1.3638345003128052
# k: 0	step: 140000/212000, loss_value: 1.190092921257019
# k: 0	step: 141000/212000, loss_value: 1.5196256637573242
# k: 0	step: 142000/212000, loss_value: 1.3489406108856201
# k: 0	step: 143000/212000, loss_value: 1.3706119060516357
# k: 0	step: 144000/212000, loss_value: 1.2473629713058472
# k: 0	step: 145000/212000, loss_value: 1.1812736988067627
# k: 0	step: 146000/212000, loss_value: 1.1857138872146606
# k: 0	step: 147000/212000, loss_value: 1.1128062009811401
# k: 0	step: 148000/212000, loss_value: 1.1054445505142212
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_148400_gaussians_github_ttn_1.5045556
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_148400_gaussians_github_ttn_1.5045556
# Accuracy: 0.4950263311878291
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.4897600936220012
#
#
# k: 0	step: 149000/212000, loss_value: 1.395938515663147
# k: 0	step: 150000/212000, loss_value: 0.9800196886062622
# k: 0	step: 151000/212000, loss_value: 1.4515953063964844
# k: 0	step: 152000/212000, loss_value: 1.645782232284546
# k: 0	step: 153000/212000, loss_value: 1.1507606506347656
# k: 0	step: 154000/212000, loss_value: 1.4938066005706787
# k: 0	step: 155000/212000, loss_value: 1.0508943796157837
# k: 0	step: 156000/212000, loss_value: 1.4817347526550293
# k: 0	step: 157000/212000, loss_value: 1.3770759105682373
# k: 0	step: 158000/212000, loss_value: 1.2255430221557617
# k: 0	step: 159000/212000, loss_value: 1.5404505729675293
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_159000_gaussians_github_ttn_1.5404506
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_159000_gaussians_github_ttn_1.5404506
# Accuracy: 0.49853715623171446
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.489174956114687
#
#
# k: 0	step: 160000/212000, loss_value: 1.4498291015625
# k: 0	step: 161000/212000, loss_value: 1.326880931854248
# k: 0	step: 162000/212000, loss_value: 1.2643802165985107
# k: 0	step: 163000/212000, loss_value: 1.2046101093292236
# k: 0	step: 164000/212000, loss_value: 1.2879316806793213
# k: 0	step: 165000/212000, loss_value: 1.388206958770752
# k: 0	step: 166000/212000, loss_value: 1.1425673961639404
# k: 0	step: 167000/212000, loss_value: 1.2578129768371582
# k: 0	step: 168000/212000, loss_value: 1.6353710889816284
# k: 0	step: 169000/212000, loss_value: 1.2727181911468506
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_169600_gaussians_github_ttn_0.9637288
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_169600_gaussians_github_ttn_0.9637288
# Accuracy: 0.4909303686366296
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.49327091866588646
#
#
# k: 0	step: 170000/212000, loss_value: 0.9066804051399231
# k: 0	step: 171000/212000, loss_value: 1.1275887489318848
# k: 0	step: 172000/212000, loss_value: 0.9263442754745483
# k: 0	step: 173000/212000, loss_value: 1.1073932647705078
# k: 0	step: 174000/212000, loss_value: 1.1998382806777954
# k: 0	step: 175000/212000, loss_value: 1.3436355590820312
# k: 0	step: 176000/212000, loss_value: 1.2664062976837158
# k: 0	step: 177000/212000, loss_value: 1.2280118465423584
# k: 0	step: 178000/212000, loss_value: 1.2840934991836548
# k: 0	step: 179000/212000, loss_value: 1.0831677913665771
# k: 0	step: 180000/212000, loss_value: 1.150360345840454
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_180200_gaussians_github_ttn_1.2721589
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_180200_gaussians_github_ttn_1.2721589
# Accuracy: 0.47981275599765943
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.49210064365125805
#
#
# k: 0	step: 181000/212000, loss_value: 1.2478153705596924
# k: 0	step: 182000/212000, loss_value: 1.7132757902145386
# k: 0	step: 183000/212000, loss_value: 1.3265093564987183
# k: 0	step: 184000/212000, loss_value: 1.4254399538040161
# k: 0	step: 185000/212000, loss_value: 0.937838613986969
# k: 0	step: 186000/212000, loss_value: 1.1711541414260864
# k: 0	step: 187000/212000, loss_value: 1.0580357313156128
# k: 0	step: 188000/212000, loss_value: 1.1700857877731323
# k: 0	step: 189000/212000, loss_value: 1.3160831928253174
# k: 0	step: 190000/212000, loss_value: 1.1657180786132812
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_190800_gaussians_github_ttn_1.3604386
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_190800_gaussians_github_ttn_1.3604386
# Accuracy: 0.4751316559391457
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.4821533060269163
#
#
# k: 0	step: 191000/212000, loss_value: 1.0422463417053223
# k: 0	step: 192000/212000, loss_value: 1.4640358686447144
# k: 0	step: 193000/212000, loss_value: 1.047837495803833
# k: 0	step: 194000/212000, loss_value: 1.415482997894287
# k: 0	step: 195000/212000, loss_value: 1.190269112586975
# k: 0	step: 196000/212000, loss_value: 1.3894315958023071
# k: 0	step: 197000/212000, loss_value: 0.9112060070037842
# k: 0	step: 198000/212000, loss_value: 1.2401994466781616
# k: 0	step: 199000/212000, loss_value: 1.1880056858062744
# k: 0	step: 200000/212000, loss_value: 1.1622881889343262
# k: 0	step: 201000/212000, loss_value: 1.306871771812439
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_201400_gaussians_github_ttn_1.247382
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_201400_gaussians_github_ttn_1.247382
# Accuracy: 0.4844938560561732
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.4885898186073727
#
#
# k: 0	step: 202000/212000, loss_value: 1.482911467552185
# k: 0	step: 203000/212000, loss_value: 1.1001476049423218
# k: 0	step: 204000/212000, loss_value: 1.2313921451568604
# k: 0	step: 205000/212000, loss_value: 1.2069768905639648
# k: 0	step: 206000/212000, loss_value: 1.260132074356079
# k: 0	step: 207000/212000, loss_value: 1.4977622032165527
# k: 0	step: 208000/212000, loss_value: 1.081479549407959
# k: 0	step: 209000/212000, loss_value: 1.1563642024993896
# k: 0	step: 210000/212000, loss_value: 1.3819763660430908
# k: 0	step: 211000/212000, loss_value: 1.0202863216400146
# k: 0	step: 212000/212000, loss_value: 1.2737561464309692
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_212000_gaussians_github_ttn_1.2737561
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_212000_gaussians_github_ttn_1.2737561
# Accuracy: 0.4897600936220012
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_best_model
# Accuracy: 0.489174956114687
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_last_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_last_model
# Accuracy: 0.483908718548859
#
#
# val_acc_json saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_val_acc.json
# log saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/0/0_train_loss.txt
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# k: 1	step: 0/212000, loss_value: 2.383225679397583
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_0_gaussians_github_ttn_2.3832257
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_0_gaussians_github_ttn_2.3832257
# Accuracy: 0.15272088940901113
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.14686951433586892
#
#
# k: 1	step: 1000/212000, loss_value: 1.770137071609497
# k: 1	step: 2000/212000, loss_value: 1.505847692489624
# k: 1	step: 3000/212000, loss_value: 1.6658804416656494
# k: 1	step: 4000/212000, loss_value: 1.571108102798462
# k: 1	step: 5000/212000, loss_value: 1.905665397644043
# k: 1	step: 6000/212000, loss_value: 1.4551960229873657
# k: 1	step: 7000/212000, loss_value: 1.6462677717208862
# k: 1	step: 8000/212000, loss_value: 1.1230950355529785
# k: 1	step: 9000/212000, loss_value: 1.4995324611663818
# k: 1	step: 10000/212000, loss_value: 1.4217071533203125
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_10600_gaussians_github_ttn_1.7375998
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_10600_gaussians_github_ttn_1.7375998
# Accuracy: 0.4511410181392627
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.45582211819777646
#
#
# k: 1	step: 11000/212000, loss_value: 1.1553401947021484
# k: 1	step: 12000/212000, loss_value: 1.4409716129302979
# k: 1	step: 13000/212000, loss_value: 1.8405283689498901
# k: 1	step: 14000/212000, loss_value: 1.431304693222046
# k: 1	step: 15000/212000, loss_value: 1.2850611209869385
# k: 1	step: 16000/212000, loss_value: 1.2865008115768433
# k: 1	step: 17000/212000, loss_value: 1.5167829990386963
# k: 1	step: 18000/212000, loss_value: 1.1956062316894531
# k: 1	step: 19000/212000, loss_value: 1.7492413520812988
# k: 1	step: 20000/212000, loss_value: 1.191291332244873
# k: 1	step: 21000/212000, loss_value: 1.4577486515045166
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_21200_gaussians_github_ttn_1.3861783
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_21200_gaussians_github_ttn_1.3861783
# Accuracy: 0.4686951433586893
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.46986541837331774
#
#
# k: 1	step: 22000/212000, loss_value: 1.1194355487823486
# k: 1	step: 23000/212000, loss_value: 1.295433521270752
# k: 1	step: 24000/212000, loss_value: 1.6394727230072021
# k: 1	step: 25000/212000, loss_value: 1.3183023929595947
# k: 1	step: 26000/212000, loss_value: 1.2654528617858887
# k: 1	step: 27000/212000, loss_value: 1.24655020236969
# k: 1	step: 28000/212000, loss_value: 1.3208086490631104
# k: 1	step: 29000/212000, loss_value: 1.135313868522644
# k: 1	step: 30000/212000, loss_value: 1.3028157949447632
# k: 1	step: 31000/212000, loss_value: 1.1584841012954712
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_31800_gaussians_github_ttn_1.7986064
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_31800_gaussians_github_ttn_1.7986064
# Accuracy: 0.4681100058513751
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.4669397308367466
#
#
# k: 1	step: 32000/212000, loss_value: 1.30202317237854
# k: 1	step: 33000/212000, loss_value: 1.866593360900879
# k: 1	step: 34000/212000, loss_value: 1.0733801126480103
# k: 1	step: 35000/212000, loss_value: 1.4108954668045044
# k: 1	step: 36000/212000, loss_value: 1.413698673248291
# k: 1	step: 37000/212000, loss_value: 1.1034181118011475
# k: 1	step: 38000/212000, loss_value: 1.3524630069732666
# k: 1	step: 39000/212000, loss_value: 1.3064072132110596
# k: 1	step: 40000/212000, loss_value: 1.1327027082443237
# k: 1	step: 41000/212000, loss_value: 1.1676123142242432
# k: 1	step: 42000/212000, loss_value: 1.6545873880386353
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_42400_gaussians_github_ttn_1.2227423
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_42400_gaussians_github_ttn_1.2227423
# Accuracy: 0.46986541837331774
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.4716208308952604
#
#
# k: 1	step: 43000/212000, loss_value: 1.5682047605514526
# k: 1	step: 44000/212000, loss_value: 1.152298927307129
# k: 1	step: 45000/212000, loss_value: 0.9780380129814148
# k: 1	step: 46000/212000, loss_value: 1.155635952949524
# k: 1	step: 47000/212000, loss_value: 1.3317722082138062
# k: 1	step: 48000/212000, loss_value: 1.329499363899231
# k: 1	step: 49000/212000, loss_value: 1.1937566995620728
# k: 1	step: 50000/212000, loss_value: 1.2659885883331299
# k: 1	step: 51000/212000, loss_value: 1.435680866241455
# k: 1	step: 52000/212000, loss_value: 1.5777373313903809
# k: 1	step: 53000/212000, loss_value: 1.1486395597457886
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_53000_gaussians_github_ttn_1.1486396
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_53000_gaussians_github_ttn_1.1486396
# Accuracy: 0.4663545933294324
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.4663545933294324
#
#
# k: 1	step: 54000/212000, loss_value: 1.517041802406311
# k: 1	step: 55000/212000, loss_value: 1.2600040435791016
# k: 1	step: 56000/212000, loss_value: 1.4805388450622559
# k: 1	step: 57000/212000, loss_value: 1.3554894924163818
# k: 1	step: 58000/212000, loss_value: 1.527172565460205
# k: 1	step: 59000/212000, loss_value: 1.4480886459350586
# k: 1	step: 60000/212000, loss_value: 1.3485445976257324
# k: 1	step: 61000/212000, loss_value: 1.1753954887390137
# k: 1	step: 62000/212000, loss_value: 1.1980010271072388
# k: 1	step: 63000/212000, loss_value: 1.3786040544509888
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_63600_gaussians_github_ttn_1.3153789
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_63600_gaussians_github_ttn_1.3153789
# Accuracy: 0.473376243417203
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.4663545933294324
#
#
# k: 1	step: 64000/212000, loss_value: 1.3713635206222534
# k: 1	step: 65000/212000, loss_value: 1.3384385108947754
# k: 1	step: 66000/212000, loss_value: 1.481570839881897
# k: 1	step: 67000/212000, loss_value: 1.4863370656967163
# k: 1	step: 68000/212000, loss_value: 1.4125896692276
# k: 1	step: 69000/212000, loss_value: 1.6957805156707764
# k: 1	step: 70000/212000, loss_value: 1.030638337135315
# k: 1	step: 71000/212000, loss_value: 1.564826250076294
# k: 1	step: 72000/212000, loss_value: 1.2808465957641602
# k: 1	step: 73000/212000, loss_value: 1.2915126085281372
# k: 1	step: 74000/212000, loss_value: 1.0829757452011108
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_74200_gaussians_github_ttn_1.1799643
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_74200_gaussians_github_ttn_1.1799643
# Accuracy: 0.46986541837331774
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.465184318314804
#
#
# k: 1	step: 75000/212000, loss_value: 1.317967176437378
# k: 1	step: 76000/212000, loss_value: 1.0872851610183716
# k: 1	step: 77000/212000, loss_value: 1.4959828853607178
# k: 1	step: 78000/212000, loss_value: 1.5687087774276733
# k: 1	step: 79000/212000, loss_value: 0.9892349243164062
# k: 1	step: 80000/212000, loss_value: 1.2484015226364136
# k: 1	step: 81000/212000, loss_value: 1.6466917991638184
# k: 1	step: 82000/212000, loss_value: 1.3641808032989502
# k: 1	step: 83000/212000, loss_value: 1.5400140285491943
# k: 1	step: 84000/212000, loss_value: 0.9425537586212158
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_84800_gaussians_github_ttn_1.1438425
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_84800_gaussians_github_ttn_1.1438425
# Accuracy: 0.4803978935049737
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.4722059684025746
#
#
# k: 1	step: 85000/212000, loss_value: 1.2987004518508911
# k: 1	step: 86000/212000, loss_value: 1.2563512325286865
# k: 1	step: 87000/212000, loss_value: 1.2530558109283447
# k: 1	step: 88000/212000, loss_value: 1.031359314918518
# k: 1	step: 89000/212000, loss_value: 1.160135269165039
# k: 1	step: 90000/212000, loss_value: 1.3469841480255127
# k: 1	step: 91000/212000, loss_value: 1.3110027313232422
# k: 1	step: 92000/212000, loss_value: 1.6487071514129639
# k: 1	step: 93000/212000, loss_value: 0.9651063680648804
# k: 1	step: 94000/212000, loss_value: 1.2870937585830688
# k: 1	step: 95000/212000, loss_value: 1.0875835418701172
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_95400_gaussians_github_ttn_1.1950564
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_95400_gaussians_github_ttn_1.1950564
# Accuracy: 0.4681100058513751
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.4745465184318315
#
#
# k: 1	step: 96000/212000, loss_value: 1.4546597003936768
# k: 1	step: 97000/212000, loss_value: 1.1175222396850586
# k: 1	step: 98000/212000, loss_value: 1.1701014041900635
# k: 1	step: 99000/212000, loss_value: 1.2298885583877563
# k: 1	step: 100000/212000, loss_value: 1.2168281078338623
# k: 1	step: 101000/212000, loss_value: 1.2439767122268677
# k: 1	step: 102000/212000, loss_value: 1.420394778251648
# k: 1	step: 103000/212000, loss_value: 1.2371004819869995
# k: 1	step: 104000/212000, loss_value: 1.4633877277374268
# k: 1	step: 105000/212000, loss_value: 1.1949557065963745
# k: 1	step: 106000/212000, loss_value: 1.0211671590805054
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_106000_gaussians_github_ttn_1.0211672
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_106000_gaussians_github_ttn_1.0211672
# Accuracy: 0.47981275599765943
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.47688706846108836
#
#
# k: 1	step: 107000/212000, loss_value: 1.0884003639221191
# k: 1	step: 108000/212000, loss_value: 1.2376947402954102
# k: 1	step: 109000/212000, loss_value: 1.3708090782165527
# k: 1	step: 110000/212000, loss_value: 1.662723422050476
# k: 1	step: 111000/212000, loss_value: 1.4740004539489746
# k: 1	step: 112000/212000, loss_value: 1.448575496673584
# k: 1	step: 113000/212000, loss_value: 1.2306090593338013
# k: 1	step: 114000/212000, loss_value: 1.3893051147460938
# k: 1	step: 115000/212000, loss_value: 1.2950607538223267
# k: 1	step: 116000/212000, loss_value: 1.0509459972381592
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_116600_gaussians_github_ttn_1.7627735
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_116600_gaussians_github_ttn_1.7627735
# Accuracy: 0.47630193095377416
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.4809830310122879
#
#
# k: 1	step: 117000/212000, loss_value: 0.9464679956436157
# k: 1	step: 118000/212000, loss_value: 1.1386427879333496
# k: 1	step: 119000/212000, loss_value: 1.2574093341827393
# k: 1	step: 120000/212000, loss_value: 1.2406892776489258
# k: 1	step: 121000/212000, loss_value: 1.5010327100753784
# k: 1	step: 122000/212000, loss_value: 1.325315237045288
# k: 1	step: 123000/212000, loss_value: 1.4701422452926636
# k: 1	step: 124000/212000, loss_value: 1.2837774753570557
# k: 1	step: 125000/212000, loss_value: 1.1515511274337769
# k: 1	step: 126000/212000, loss_value: 1.759207010269165
# k: 1	step: 127000/212000, loss_value: 1.3177258968353271
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_127200_gaussians_github_ttn_1.3409404
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_127200_gaussians_github_ttn_1.3409404
# Accuracy: 0.4727911059098888
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.473376243417203
#
#
# k: 1	step: 128000/212000, loss_value: 1.3606629371643066
# k: 1	step: 129000/212000, loss_value: 1.0953116416931152
# k: 1	step: 130000/212000, loss_value: 1.199199914932251
# k: 1	step: 131000/212000, loss_value: 1.1223738193511963
# k: 1	step: 132000/212000, loss_value: 1.1878514289855957
# k: 1	step: 133000/212000, loss_value: 1.0472540855407715
# k: 1	step: 134000/212000, loss_value: 1.431868553161621
# k: 1	step: 135000/212000, loss_value: 1.0223820209503174
# k: 1	step: 136000/212000, loss_value: 1.2572836875915527
# k: 1	step: 137000/212000, loss_value: 1.5107192993164062
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_137800_gaussians_github_ttn_1.6233491
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_137800_gaussians_github_ttn_1.6233491
# Accuracy: 0.4722059684025746
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.46986541837331774
#
#
# k: 1	step: 138000/212000, loss_value: 1.3699661493301392
# k: 1	step: 139000/212000, loss_value: 1.2132906913757324
# k: 1	step: 140000/212000, loss_value: 1.01175057888031
# k: 1	step: 141000/212000, loss_value: 1.2832427024841309
# k: 1	step: 142000/212000, loss_value: 1.1414382457733154
# k: 1	step: 143000/212000, loss_value: 1.8409262895584106
# k: 1	step: 144000/212000, loss_value: 1.033908724784851
# k: 1	step: 145000/212000, loss_value: 1.0573134422302246
# k: 1	step: 146000/212000, loss_value: 1.1796056032180786
# k: 1	step: 147000/212000, loss_value: 1.3398981094360352
# k: 1	step: 148000/212000, loss_value: 1.2262805700302124
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_148400_gaussians_github_ttn_1.348996
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_148400_gaussians_github_ttn_1.348996
# Accuracy: 0.4745465184318315
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.47922761849034523
#
#
# k: 1	step: 149000/212000, loss_value: 1.0887787342071533
# k: 1	step: 150000/212000, loss_value: 1.2754367589950562
# k: 1	step: 151000/212000, loss_value: 1.4648914337158203
# k: 1	step: 152000/212000, loss_value: 1.0483808517456055
# k: 1	step: 153000/212000, loss_value: 1.0345630645751953
# k: 1	step: 154000/212000, loss_value: 1.4041645526885986
# k: 1	step: 155000/212000, loss_value: 1.3258850574493408
# k: 1	step: 156000/212000, loss_value: 1.3380022048950195
# k: 1	step: 157000/212000, loss_value: 1.2045197486877441
# k: 1	step: 158000/212000, loss_value: 1.3937095403671265
# k: 1	step: 159000/212000, loss_value: 1.311338186264038
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_159000_gaussians_github_ttn_1.3113382
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_159000_gaussians_github_ttn_1.3113382
# Accuracy: 0.47045055588063195
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/1/1_best_model
# Accuracy: 0.48273844353423057
#
#
# k: 1	step: 160000/212000, loss_value: 1.4265742301940918
# k: 1	step: 161000/212000, loss_value: 1.1819645166397095
# k: 1	step: 162000/212000, loss_value: 1.10593581199646
# ...
# k: 2	step: 87000/212000, loss_value: 1.1588490009307861
# k: 2	step: 88000/212000, loss_value: 1.282038927078247
# k: 2	step: 89000/212000, loss_value: 1.3367292881011963
# k: 2	step: 90000/212000, loss_value: 1.442030429840088
# k: 2	step: 91000/212000, loss_value: 1.4297163486480713
# k: 2	step: 92000/212000, loss_value: 1.4621779918670654
# k: 2	step: 93000/212000, loss_value: 1.4276719093322754
# k: 2	step: 94000/212000, loss_value: 1.4384050369262695
# k: 2	step: 95000/212000, loss_value: 1.1443816423416138
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_95400_gaussians_github_ttn_1.1516309
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_95400_gaussians_github_ttn_1.1516309
# Accuracy: 0.4689695550351288
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# Accuracy: 0.47365339578454335
#
#
# k: 2	step: 96000/212000, loss_value: 1.1640244722366333
# k: 2	step: 97000/212000, loss_value: 1.172377586364746
# k: 2	step: 98000/212000, loss_value: 1.4471726417541504
# k: 2	step: 99000/212000, loss_value: 1.7526912689208984
# k: 2	step: 100000/212000, loss_value: 0.9959173798561096
# k: 2	step: 101000/212000, loss_value: 1.138767957687378
# k: 2	step: 102000/212000, loss_value: 1.2615967988967896
# k: 2	step: 103000/212000, loss_value: 1.167980670928955
# k: 2	step: 104000/212000, loss_value: 1.1312057971954346
# k: 2	step: 105000/212000, loss_value: 1.2173571586608887
# k: 2	step: 106000/212000, loss_value: 1.1616675853729248
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_106000_gaussians_github_ttn_1.1616676
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_106000_gaussians_github_ttn_1.1616676
# Accuracy: 0.4637002341920375
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# Accuracy: 0.46662763466042156
#
#
# k: 2	step: 107000/212000, loss_value: 1.0791280269622803
# k: 2	step: 108000/212000, loss_value: 1.321442723274231
# k: 2	step: 109000/212000, loss_value: 0.8702705502510071
# k: 2	step: 110000/212000, loss_value: 1.2156813144683838
# k: 2	step: 111000/212000, loss_value: 1.1368598937988281
# k: 2	step: 112000/212000, loss_value: 1.451535940170288
# k: 2	step: 113000/212000, loss_value: 1.0146174430847168
# k: 2	step: 114000/212000, loss_value: 1.5259006023406982
# k: 2	step: 115000/212000, loss_value: 1.2289741039276123
# k: 2	step: 116000/212000, loss_value: 1.5589919090270996
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_116600_gaussians_github_ttn_1.3171763
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_116600_gaussians_github_ttn_1.3171763
# Accuracy: 0.4724824355971897
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# Accuracy: 0.46545667447306793
#
#
# k: 2	step: 117000/212000, loss_value: 1.340525507926941
# k: 2	step: 118000/212000, loss_value: 1.3244707584381104
# k: 2	step: 119000/212000, loss_value: 1.529557228088379
# k: 2	step: 120000/212000, loss_value: 1.6360348463058472
# k: 2	step: 121000/212000, loss_value: 1.2459782361984253
# k: 2	step: 122000/212000, loss_value: 1.3575174808502197
# k: 2	step: 123000/212000, loss_value: 1.1967964172363281
# k: 2	step: 124000/212000, loss_value: 1.1500681638717651
# k: 2	step: 125000/212000, loss_value: 1.2466994524002075
# k: 2	step: 126000/212000, loss_value: 1.3863332271575928
# k: 2	step: 127000/212000, loss_value: 1.2503385543823242
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_127200_gaussians_github_ttn_0.9232998
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_127200_gaussians_github_ttn_0.9232998
# Accuracy: 0.46955503512880564
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# Accuracy: 0.4783372365339578
#
#
# k: 2	step: 128000/212000, loss_value: 1.1475021839141846
# k: 2	step: 129000/212000, loss_value: 1.2324192523956299
# k: 2	step: 130000/212000, loss_value: 1.2501592636108398
# k: 2	step: 131000/212000, loss_value: 1.2505621910095215
# k: 2	step: 132000/212000, loss_value: 1.802924633026123
# k: 2	step: 133000/212000, loss_value: 1.3375437259674072
# k: 2	step: 134000/212000, loss_value: 1.0676488876342773
# k: 2	step: 135000/212000, loss_value: 1.1689152717590332
# k: 2	step: 136000/212000, loss_value: 1.422698974609375
# k: 2	step: 137000/212000, loss_value: 0.9579393267631531
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_137800_gaussians_github_ttn_1.2720451
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_137800_gaussians_github_ttn_1.2720451
# Accuracy: 0.4765807962529274
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# Accuracy: 0.474824355971897
#
#
# k: 2	step: 138000/212000, loss_value: 1.335630178451538
# k: 2	step: 139000/212000, loss_value: 1.2842741012573242
# k: 2	step: 140000/212000, loss_value: 1.6891099214553833
# k: 2	step: 141000/212000, loss_value: 1.116666316986084
# k: 2	step: 142000/212000, loss_value: 1.3443920612335205
# k: 2	step: 143000/212000, loss_value: 1.209653377532959
# k: 2	step: 144000/212000, loss_value: 1.0408527851104736
# k: 2	step: 145000/212000, loss_value: 1.0045585632324219
# k: 2	step: 146000/212000, loss_value: 1.08599853515625
# k: 2	step: 147000/212000, loss_value: 1.2496031522750854
# k: 2	step: 148000/212000, loss_value: 1.2013051509857178
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_148400_gaussians_github_ttn_1.2745802
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_148400_gaussians_github_ttn_1.2745802
# Accuracy: 0.468384074941452
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# Accuracy: 0.4637002341920375
#
#
# k: 2	step: 149000/212000, loss_value: 1.302964448928833
# k: 2	step: 150000/212000, loss_value: 1.6267881393432617
# k: 2	step: 151000/212000, loss_value: 1.1830041408538818
# k: 2	step: 152000/212000, loss_value: 1.316875696182251
# k: 2	step: 153000/212000, loss_value: 1.1162636280059814
# k: 2	step: 154000/212000, loss_value: 2.037811756134033
# k: 2	step: 155000/212000, loss_value: 1.1222378015518188
# k: 2	step: 156000/212000, loss_value: 1.2248461246490479
# k: 2	step: 157000/212000, loss_value: 1.5242215394973755
# k: 2	step: 158000/212000, loss_value: 1.0963459014892578
# k: 2	step: 159000/212000, loss_value: 1.2724171876907349
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_159000_gaussians_github_ttn_1.2724172
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_159000_gaussians_github_ttn_1.2724172
# Accuracy: 0.4713114754098361
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# Accuracy: 0.48302107728337235
#
#
# k: 2	step: 160000/212000, loss_value: 1.2221004962921143
# k: 2	step: 161000/212000, loss_value: 1.1370689868927002
# k: 2	step: 162000/212000, loss_value: 1.0207571983337402
# k: 2	step: 163000/212000, loss_value: 1.0849090814590454
# k: 2	step: 164000/212000, loss_value: 1.2207601070404053
# k: 2	step: 165000/212000, loss_value: 1.3067489862442017
# k: 2	step: 166000/212000, loss_value: 1.187617301940918
# k: 2	step: 167000/212000, loss_value: 1.269294023513794
# k: 2	step: 168000/212000, loss_value: 1.3142311573028564
# k: 2	step: 169000/212000, loss_value: 1.113877296447754
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_169600_gaussians_github_ttn_1.0390122
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_169600_gaussians_github_ttn_1.0390122
# Accuracy: 0.474824355971897
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# Accuracy: 0.4707259953161593
#
#
# k: 2	step: 170000/212000, loss_value: 0.9244347810745239
# k: 2	step: 171000/212000, loss_value: 1.1855299472808838
# k: 2	step: 172000/212000, loss_value: 1.256340742111206
# k: 2	step: 173000/212000, loss_value: 1.2990965843200684
# k: 2	step: 174000/212000, loss_value: 1.355198621749878
# k: 2	step: 175000/212000, loss_value: 1.4065823554992676
# k: 2	step: 176000/212000, loss_value: 1.2006785869598389
# k: 2	step: 177000/212000, loss_value: 1.3531475067138672
# k: 2	step: 178000/212000, loss_value: 1.3503973484039307
# k: 2	step: 179000/212000, loss_value: 1.3881032466888428
# k: 2	step: 180000/212000, loss_value: 1.2911328077316284
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_180200_gaussians_github_ttn_1.2070999
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_180200_gaussians_github_ttn_1.2070999
# Accuracy: 0.474824355971897
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# Accuracy: 0.4677985948477752
#
#
# k: 2	step: 181000/212000, loss_value: 1.2350590229034424
# k: 2	step: 182000/212000, loss_value: 1.0624431371688843
# k: 2	step: 183000/212000, loss_value: 1.1146681308746338
# k: 2	step: 184000/212000, loss_value: 1.3514704704284668
# k: 2	step: 185000/212000, loss_value: 1.1705763339996338
# k: 2	step: 186000/212000, loss_value: 0.7910434007644653
# k: 2	step: 187000/212000, loss_value: 1.4275110960006714
# k: 2	step: 188000/212000, loss_value: 1.0787274837493896
# k: 2	step: 189000/212000, loss_value: 1.3335795402526855
# k: 2	step: 190000/212000, loss_value: 0.994381844997406
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_190800_gaussians_github_ttn_1.113569
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_190800_gaussians_github_ttn_1.113569
# Accuracy: 0.46311475409836067
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# Accuracy: 0.47014051522248246
#
#
# k: 2	step: 191000/212000, loss_value: 1.1752686500549316
# k: 2	step: 192000/212000, loss_value: 1.1536108255386353
# k: 2	step: 193000/212000, loss_value: 1.265838384628296
# k: 2	step: 194000/212000, loss_value: 1.0204036235809326
# k: 2	step: 195000/212000, loss_value: 1.355601191520691
# k: 2	step: 196000/212000, loss_value: 1.2531394958496094
# k: 2	step: 197000/212000, loss_value: 1.4814283847808838
# k: 2	step: 198000/212000, loss_value: 1.2214112281799316
# k: 2	step: 199000/212000, loss_value: 1.18282151222229
# k: 2	step: 200000/212000, loss_value: 1.1225605010986328
# k: 2	step: 201000/212000, loss_value: 1.353492021560669
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_201400_gaussians_github_ttn_0.7995503
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_201400_gaussians_github_ttn_0.7995503
# Accuracy: 0.46194379391100704
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# Accuracy: 0.4648711943793911
#
#
# k: 2	step: 202000/212000, loss_value: 1.1676521301269531
# k: 2	step: 203000/212000, loss_value: 1.0569517612457275
# k: 2	step: 204000/212000, loss_value: 1.024324655532837
# k: 2	step: 205000/212000, loss_value: 1.3080533742904663
# k: 2	step: 206000/212000, loss_value: 1.4977140426635742
# k: 2	step: 207000/212000, loss_value: 1.2510111331939697
# k: 2	step: 208000/212000, loss_value: 1.2542245388031006
# k: 2	step: 209000/212000, loss_value: 1.4356248378753662
# k: 2	step: 210000/212000, loss_value: 1.025012731552124
# k: 2	step: 211000/212000, loss_value: 0.9996800422668457
# k: 2	step: 212000/212000, loss_value: 1.3713172674179077
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_212000_gaussians_github_ttn_1.3713173
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_212000_gaussians_github_ttn_1.3713173
# Accuracy: 0.46662763466042156
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_best_model
# Accuracy: 0.47365339578454335
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_last_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/9999/npy/3/kyoto11-train-x-2.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_last_model
# Accuracy: 0.47599531615925056
#
#
# val_acc_json saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_val_acc.json
# log saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/9999/2/2_train_loss.txt
#
#
# k:	best	last
# 0:	0.489174956114687	0.483908718548859
# 1:	0.47045055588063195	0.47103569338794615
# 2:	0.47365339578454335	0.47599531615925056
#
# CPU times: user 1h 47min 25s, sys: 13min 19s, total: 2h 45s
# Wall time: 1h 31min 8s

# %% [markdown]
# ```bash
#
# ```

# %% [markdown]
# # <a id='C'>C</a>

# %%
# %%time
dict_cus["distance_int"] = 999
train_ttn(dict_cus)
# Out:
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# k: 0	step: 0/212000, loss_value: 2.393108367919922
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_0_gaussians_github_ttn_2.3931084
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_0_gaussians_github_ttn_2.3931084
# Accuracy: 0.14394382679929785
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_best_model
# Accuracy: 0.1486249268578116
#
#
# k: 0	step: 1000/212000, loss_value: nan
# k: 0	step: 2000/212000, loss_value: nan
# k: 0	step: 3000/212000, loss_value: nan
# k: 0	step: 4000/212000, loss_value: nan
# k: 0	step: 5000/212000, loss_value: nan
# k: 0	step: 6000/212000, loss_value: nan
# k: 0	step: 7000/212000, loss_value: nan
# k: 0	step: 8000/212000, loss_value: nan
# k: 0	step: 9000/212000, loss_value: nan
# k: 0	step: 10000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_10600_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_10600_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 11000/212000, loss_value: nan
# k: 0	step: 12000/212000, loss_value: nan
# k: 0	step: 13000/212000, loss_value: nan
# k: 0	step: 14000/212000, loss_value: nan
# k: 0	step: 15000/212000, loss_value: nan
# k: 0	step: 16000/212000, loss_value: nan
# k: 0	step: 17000/212000, loss_value: nan
# k: 0	step: 18000/212000, loss_value: nan
# k: 0	step: 19000/212000, loss_value: nan
# k: 0	step: 20000/212000, loss_value: nan
# k: 0	step: 21000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_21200_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_21200_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 22000/212000, loss_value: nan
# k: 0	step: 23000/212000, loss_value: nan
# k: 0	step: 24000/212000, loss_value: nan
# k: 0	step: 25000/212000, loss_value: nan
# k: 0	step: 26000/212000, loss_value: nan
# k: 0	step: 27000/212000, loss_value: nan
# k: 0	step: 28000/212000, loss_value: nan
# k: 0	step: 29000/212000, loss_value: nan
# k: 0	step: 30000/212000, loss_value: nan
# k: 0	step: 31000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_31800_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_31800_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 32000/212000, loss_value: nan
# k: 0	step: 33000/212000, loss_value: nan
# k: 0	step: 34000/212000, loss_value: nan
# k: 0	step: 35000/212000, loss_value: nan
# k: 0	step: 36000/212000, loss_value: nan
# k: 0	step: 37000/212000, loss_value: nan
# k: 0	step: 38000/212000, loss_value: nan
# k: 0	step: 39000/212000, loss_value: nan
# k: 0	step: 40000/212000, loss_value: nan
# k: 0	step: 41000/212000, loss_value: nan
# k: 0	step: 42000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_42400_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_42400_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 43000/212000, loss_value: nan
# k: 0	step: 44000/212000, loss_value: nan
# k: 0	step: 45000/212000, loss_value: nan
# k: 0	step: 46000/212000, loss_value: nan
# k: 0	step: 47000/212000, loss_value: nan
# k: 0	step: 48000/212000, loss_value: nan
# k: 0	step: 49000/212000, loss_value: nan
# k: 0	step: 50000/212000, loss_value: nan
# k: 0	step: 51000/212000, loss_value: nan
# k: 0	step: 52000/212000, loss_value: nan
# k: 0	step: 53000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_53000_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_53000_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 54000/212000, loss_value: nan
# k: 0	step: 55000/212000, loss_value: nan
# k: 0	step: 56000/212000, loss_value: nan
# k: 0	step: 57000/212000, loss_value: nan
# k: 0	step: 58000/212000, loss_value: nan
# k: 0	step: 59000/212000, loss_value: nan
# k: 0	step: 60000/212000, loss_value: nan
# k: 0	step: 61000/212000, loss_value: nan
# k: 0	step: 62000/212000, loss_value: nan
# k: 0	step: 63000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_63600_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_63600_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 64000/212000, loss_value: nan
# k: 0	step: 65000/212000, loss_value: nan
# k: 0	step: 66000/212000, loss_value: nan
# k: 0	step: 67000/212000, loss_value: nan
# k: 0	step: 68000/212000, loss_value: nan
# k: 0	step: 69000/212000, loss_value: nan
# k: 0	step: 70000/212000, loss_value: nan
# k: 0	step: 71000/212000, loss_value: nan
# k: 0	step: 72000/212000, loss_value: nan
# k: 0	step: 73000/212000, loss_value: nan
# k: 0	step: 74000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_74200_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_74200_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 75000/212000, loss_value: nan
# k: 0	step: 76000/212000, loss_value: nan
# k: 0	step: 77000/212000, loss_value: nan
# k: 0	step: 78000/212000, loss_value: nan
# k: 0	step: 79000/212000, loss_value: nan
# k: 0	step: 80000/212000, loss_value: nan
# k: 0	step: 81000/212000, loss_value: nan
# k: 0	step: 82000/212000, loss_value: nan
# k: 0	step: 83000/212000, loss_value: nan
# k: 0	step: 84000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_84800_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_84800_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 85000/212000, loss_value: nan
# k: 0	step: 86000/212000, loss_value: nan
# k: 0	step: 87000/212000, loss_value: nan
# k: 0	step: 88000/212000, loss_value: nan
# k: 0	step: 89000/212000, loss_value: nan
# k: 0	step: 90000/212000, loss_value: nan
# k: 0	step: 91000/212000, loss_value: nan
# k: 0	step: 92000/212000, loss_value: nan
# k: 0	step: 93000/212000, loss_value: nan
# k: 0	step: 94000/212000, loss_value: nan
# k: 0	step: 95000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_95400_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_95400_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 96000/212000, loss_value: nan
# k: 0	step: 97000/212000, loss_value: nan
# k: 0	step: 98000/212000, loss_value: nan
# k: 0	step: 99000/212000, loss_value: nan
# k: 0	step: 100000/212000, loss_value: nan
# k: 0	step: 101000/212000, loss_value: nan
# k: 0	step: 102000/212000, loss_value: nan
# k: 0	step: 103000/212000, loss_value: nan
# k: 0	step: 104000/212000, loss_value: nan
# k: 0	step: 105000/212000, loss_value: nan
# k: 0	step: 106000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_106000_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_106000_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 107000/212000, loss_value: nan
# k: 0	step: 108000/212000, loss_value: nan
# k: 0	step: 109000/212000, loss_value: nan
# k: 0	step: 110000/212000, loss_value: nan
# k: 0	step: 111000/212000, loss_value: nan
# k: 0	step: 112000/212000, loss_value: nan
# k: 0	step: 113000/212000, loss_value: nan
# k: 0	step: 114000/212000, loss_value: nan
# k: 0	step: 115000/212000, loss_value: nan
# k: 0	step: 116000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_116600_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_116600_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 117000/212000, loss_value: nan
# k: 0	step: 118000/212000, loss_value: nan
# k: 0	step: 119000/212000, loss_value: nan
# k: 0	step: 120000/212000, loss_value: nan
# k: 0	step: 121000/212000, loss_value: nan
# k: 0	step: 122000/212000, loss_value: nan
# k: 0	step: 123000/212000, loss_value: nan
# k: 0	step: 124000/212000, loss_value: nan
# k: 0	step: 125000/212000, loss_value: nan
# k: 0	step: 126000/212000, loss_value: nan
# k: 0	step: 127000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_127200_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_127200_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 128000/212000, loss_value: nan
# k: 0	step: 129000/212000, loss_value: nan
# k: 0	step: 130000/212000, loss_value: nan
# k: 0	step: 131000/212000, loss_value: nan
# k: 0	step: 132000/212000, loss_value: nan
# k: 0	step: 133000/212000, loss_value: nan
# k: 0	step: 134000/212000, loss_value: nan
# k: 0	step: 135000/212000, loss_value: nan
# k: 0	step: 136000/212000, loss_value: nan
# k: 0	step: 137000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_137800_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_137800_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 138000/212000, loss_value: nan
# k: 0	step: 139000/212000, loss_value: nan
# k: 0	step: 140000/212000, loss_value: nan
# k: 0	step: 141000/212000, loss_value: nan
# k: 0	step: 142000/212000, loss_value: nan
# k: 0	step: 143000/212000, loss_value: nan
# k: 0	step: 144000/212000, loss_value: nan
# k: 0	step: 145000/212000, loss_value: nan
# k: 0	step: 146000/212000, loss_value: nan
# k: 0	step: 147000/212000, loss_value: nan
# k: 0	step: 148000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_148400_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_148400_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 149000/212000, loss_value: nan
# k: 0	step: 150000/212000, loss_value: nan
# k: 0	step: 151000/212000, loss_value: nan
# k: 0	step: 152000/212000, loss_value: nan
# k: 0	step: 153000/212000, loss_value: nan
# k: 0	step: 154000/212000, loss_value: nan
# k: 0	step: 155000/212000, loss_value: nan
# k: 0	step: 156000/212000, loss_value: nan
# k: 0	step: 157000/212000, loss_value: nan
# k: 0	step: 158000/212000, loss_value: nan
# k: 0	step: 159000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_159000_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_159000_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 160000/212000, loss_value: nan
# k: 0	step: 161000/212000, loss_value: nan
# k: 0	step: 162000/212000, loss_value: nan
# k: 0	step: 163000/212000, loss_value: nan
# k: 0	step: 164000/212000, loss_value: nan
# k: 0	step: 165000/212000, loss_value: nan
# k: 0	step: 166000/212000, loss_value: nan
# k: 0	step: 167000/212000, loss_value: nan
# k: 0	step: 168000/212000, loss_value: nan
# k: 0	step: 169000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_169600_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_169600_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 170000/212000, loss_value: nan
# k: 0	step: 171000/212000, loss_value: nan
# k: 0	step: 172000/212000, loss_value: nan
# k: 0	step: 173000/212000, loss_value: nan
# k: 0	step: 174000/212000, loss_value: nan
# k: 0	step: 175000/212000, loss_value: nan
# k: 0	step: 176000/212000, loss_value: nan
# k: 0	step: 177000/212000, loss_value: nan
# k: 0	step: 178000/212000, loss_value: nan
# k: 0	step: 179000/212000, loss_value: nan
# k: 0	step: 180000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_180200_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_180200_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 181000/212000, loss_value: nan
# k: 0	step: 182000/212000, loss_value: nan
# k: 0	step: 183000/212000, loss_value: nan
# k: 0	step: 184000/212000, loss_value: nan
# k: 0	step: 185000/212000, loss_value: nan
# k: 0	step: 186000/212000, loss_value: nan
# k: 0	step: 187000/212000, loss_value: nan
# k: 0	step: 188000/212000, loss_value: nan
# k: 0	step: 189000/212000, loss_value: nan
# k: 0	step: 190000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_190800_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_190800_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 191000/212000, loss_value: nan
# k: 0	step: 192000/212000, loss_value: nan
# k: 0	step: 193000/212000, loss_value: nan
# k: 0	step: 194000/212000, loss_value: nan
# k: 0	step: 195000/212000, loss_value: nan
# k: 0	step: 196000/212000, loss_value: nan
# k: 0	step: 197000/212000, loss_value: nan
# k: 0	step: 198000/212000, loss_value: nan
# k: 0	step: 199000/212000, loss_value: nan
# k: 0	step: 200000/212000, loss_value: nan
# k: 0	step: 201000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_201400_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_201400_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# k: 0	step: 202000/212000, loss_value: nan
# k: 0	step: 203000/212000, loss_value: nan
# k: 0	step: 204000/212000, loss_value: nan
# k: 0	step: 205000/212000, loss_value: nan
# k: 0	step: 206000/212000, loss_value: nan
# k: 0	step: 207000/212000, loss_value: nan
# k: 0	step: 208000/212000, loss_value: nan
# k: 0	step: 209000/212000, loss_value: nan
# k: 0	step: 210000/212000, loss_value: nan
# k: 0	step: 211000/212000, loss_value: nan
# k: 0	step: 212000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_212000_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_212000_gaussians_github_ttn_nan
# Accuracy: 0.2738443534230544
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_last_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_last_model
# Accuracy: 0.2738443534230544
#
#
# val_acc_json saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_val_acc.json
# log saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/0/0_train_loss.txt
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# k: 1	step: 0/212000, loss_value: 2.396249771118164
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_0_gaussians_github_ttn_2.3962498
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_0_gaussians_github_ttn_2.3962498
# Accuracy: 0.15096547688706846
#
#
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_best_model
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_best_model
# Accuracy: 0.15623171445289644
#
#
# k: 1	step: 1000/212000, loss_value: nan
# k: 1	step: 2000/212000, loss_value: nan
# k: 1	step: 3000/212000, loss_value: nan
# k: 1	step: 4000/212000, loss_value: nan
# k: 1	step: 5000/212000, loss_value: nan
# k: 1	step: 6000/212000, loss_value: nan
# k: 1	step: 7000/212000, loss_value: nan
# k: 1	step: 8000/212000, loss_value: nan
# k: 1	step: 9000/212000, loss_value: nan
# k: 1	step: 10000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_10600_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_10600_gaussians_github_ttn_nan
# Accuracy: 0.2732592159157402
#
#
# k: 1	step: 11000/212000, loss_value: nan
# k: 1	step: 12000/212000, loss_value: nan
# k: 1	step: 13000/212000, loss_value: nan
# k: 1	step: 14000/212000, loss_value: nan
# k: 1	step: 15000/212000, loss_value: nan
# k: 1	step: 16000/212000, loss_value: nan
# k: 1	step: 17000/212000, loss_value: nan
# k: 1	step: 18000/212000, loss_value: nan
# k: 1	step: 19000/212000, loss_value: nan
# k: 1	step: 20000/212000, loss_value: nan
# k: 1	step: 21000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_21200_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_21200_gaussians_github_ttn_nan
# Accuracy: 0.2732592159157402
#
#
# k: 1	step: 22000/212000, loss_value: nan
# k: 1	step: 23000/212000, loss_value: nan
# k: 1	step: 24000/212000, loss_value: nan
# k: 1	step: 25000/212000, loss_value: nan
# k: 1	step: 26000/212000, loss_value: nan
# k: 1	step: 27000/212000, loss_value: nan
# k: 1	step: 28000/212000, loss_value: nan
# k: 1	step: 29000/212000, loss_value: nan
# k: 1	step: 30000/212000, loss_value: nan
# k: 1	step: 31000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_31800_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_31800_gaussians_github_ttn_nan
# Accuracy: 0.2732592159157402
#
#
# k: 1	step: 32000/212000, loss_value: nan
# k: 1	step: 33000/212000, loss_value: nan
# k: 1	step: 34000/212000, loss_value: nan
# k: 1	step: 35000/212000, loss_value: nan
# k: 1	step: 36000/212000, loss_value: nan
# k: 1	step: 37000/212000, loss_value: nan
# k: 1	step: 38000/212000, loss_value: nan
# k: 1	step: 39000/212000, loss_value: nan
# k: 1	step: 40000/212000, loss_value: nan
# k: 1	step: 41000/212000, loss_value: nan
# k: 1	step: 42000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_42400_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_42400_gaussians_github_ttn_nan
# Accuracy: 0.2732592159157402
#
#
# k: 1	step: 43000/212000, loss_value: nan
# k: 1	step: 44000/212000, loss_value: nan
# k: 1	step: 45000/212000, loss_value: nan
# k: 1	step: 46000/212000, loss_value: nan
# k: 1	step: 47000/212000, loss_value: nan
# k: 1	step: 48000/212000, loss_value: nan
# k: 1	step: 49000/212000, loss_value: nan
# k: 1	step: 50000/212000, loss_value: nan
# k: 1	step: 51000/212000, loss_value: nan
# k: 1	step: 52000/212000, loss_value: nan
# k: 1	step: 53000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_53000_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_53000_gaussians_github_ttn_nan
# Accuracy: 0.2732592159157402
#
#
# k: 1	step: 54000/212000, loss_value: nan
# k: 1	step: 55000/212000, loss_value: nan
# k: 1	step: 56000/212000, loss_value: nan
# k: 1	step: 57000/212000, loss_value: nan
# k: 1	step: 58000/212000, loss_value: nan
# k: 1	step: 59000/212000, loss_value: nan
# k: 1	step: 60000/212000, loss_value: nan
# k: 1	step: 61000/212000, loss_value: nan
# k: 1	step: 62000/212000, loss_value: nan
# k: 1	step: 63000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_63600_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_63600_gaussians_github_ttn_nan
# Accuracy: 0.2732592159157402
#
#
# k: 1	step: 64000/212000, loss_value: nan
# k: 1	step: 65000/212000, loss_value: nan
# k: 1	step: 66000/212000, loss_value: nan
# k: 1	step: 67000/212000, loss_value: nan
# k: 1	step: 68000/212000, loss_value: nan
# k: 1	step: 69000/212000, loss_value: nan
# k: 1	step: 70000/212000, loss_value: nan
# k: 1	step: 71000/212000, loss_value: nan
# k: 1	step: 72000/212000, loss_value: nan
# k: 1	step: 73000/212000, loss_value: nan
# k: 1	step: 74000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_74200_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_74200_gaussians_github_ttn_nan
# Accuracy: 0.2732592159157402
#
#
# k: 1	step: 75000/212000, loss_value: nan
# k: 1	step: 76000/212000, loss_value: nan
# k: 1	step: 77000/212000, loss_value: nan
# k: 1	step: 78000/212000, loss_value: nan
# k: 1	step: 79000/212000, loss_value: nan
# k: 1	step: 80000/212000, loss_value: nan
# k: 1	step: 81000/212000, loss_value: nan
# k: 1	step: 82000/212000, loss_value: nan
# k: 1	step: 83000/212000, loss_value: nan
# k: 1	step: 84000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_84800_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_84800_gaussians_github_ttn_nan
# Accuracy: 0.2732592159157402
#
#
# k: 1	step: 85000/212000, loss_value: nan
# k: 1	step: 86000/212000, loss_value: nan
# k: 1	step: 87000/212000, loss_value: nan
# k: 1	step: 88000/212000, loss_value: nan
# k: 1	step: 89000/212000, loss_value: nan
# k: 1	step: 90000/212000, loss_value: nan
# k: 1	step: 91000/212000, loss_value: nan
# k: 1	step: 92000/212000, loss_value: nan
# k: 1	step: 93000/212000, loss_value: nan
# k: 1	step: 94000/212000, loss_value: nan
# k: 1	step: 95000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_95400_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_95400_gaussians_github_ttn_nan
# Accuracy: 0.2732592159157402
#
#
# k: 1	step: 96000/212000, loss_value: nan
# k: 1	step: 97000/212000, loss_value: nan
# k: 1	step: 98000/212000, loss_value: nan
# k: 1	step: 99000/212000, loss_value: nan
# k: 1	step: 100000/212000, loss_value: nan
# k: 1	step: 101000/212000, loss_value: nan
# k: 1	step: 102000/212000, loss_value: nan
# k: 1	step: 103000/212000, loss_value: nan
# k: 1	step: 104000/212000, loss_value: nan
# k: 1	step: 105000/212000, loss_value: nan
# k: 1	step: 106000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_106000_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_106000_gaussians_github_ttn_nan
# Accuracy: 0.2732592159157402
#
#
# k: 1	step: 107000/212000, loss_value: nan
# k: 1	step: 108000/212000, loss_value: nan
# k: 1	step: 109000/212000, loss_value: nan
# k: 1	step: 110000/212000, loss_value: nan
# k: 1	step: 111000/212000, loss_value: nan
# k: 1	step: 112000/212000, loss_value: nan
# k: 1	step: 113000/212000, loss_value: nan
# k: 1	step: 114000/212000, loss_value: nan
# k: 1	step: 115000/212000, loss_value: nan
# k: 1	step: 116000/212000, loss_value: nan
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_116600_gaussians_github_ttn_nan
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/999/npy/3/kyoto11-train-x-1.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/999/1/1_116600_gaussians_github_ttn_nan
# Accuracy: 0.2732592159157402
#
#
# k: 1	step: 117000/212000, loss_value: nan
# k: 1	step: 118000/212000, loss_value: nan
# k: 1	step: 119000/212000, loss_value: nan
# k: 1	step: 120000/212000, loss_value: nan
# k: 1	step: 121000/212000, loss_value: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/project/paperEdit/haredit-ttn/train_network_synthetic.py in train_ttn(dict_cus)
#      95                                          feed_dict={x_placeholder: train_data[trainIdx, :],
#      96                                                     y_placeholder: train_label[trainIdx, :],
# ---> 97                                                     learning_rate_placeholder: learning_rate_1})
#      98                 train_loss.append(loss_value)
#      99
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122
#    1123           if (not is_tensor_handle_feed and
# -> 1124               not subfeed_t.get_shape().is_compatible_with(np_val.shape)):
#    1125             raise ValueError('Cannot feed value of shape %r for Tensor %r, '
#    1126                              'which has shape %r' %
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_shape(self)
#     492   def get_shape(self):
#     493     """Alias of Tensor.shape."""
# --> 494     return self.shape
#     495
#     496   def set_shape(self, shape):
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in shape(self)
#     405
#     406     """
# --> 407     if self._shape_val is None:
#     408       if _USE_C_SHAPES:
#     409         self._shape_val = self._c_api_shape()
#
# KeyboardInterrupt:

# %% [markdown]
# ```bash
#
# ```

# %% [markdown]
# # <a id='constrain_1'>CS_1</a>

# %%
# %%time
dict_cus["distance_int"] = 1
train_ttn(dict_cus)
# Out:
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/1/npy/3/kyoto11-train-x-0.npy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in gather(***failed resolving arguments***)
#    2672     # introducing a circular dependency.
# -> 2673     return params.sparse_read(indices, name=name)
#    2674   except AttributeError:
#
# AttributeError: 'Tensor' object has no attribute 'sparse_read'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/project/paperEdit/haredit-ttn/train_network_synthetic.py in train_ttn(dict_cus)
#      57
#      58             output, sequence_unwarped, gamma, sequence1 = network.mapping(x_placeholder, batch_size,
# ---> 59                                                                           configure.parameters_dict["seq_len"])
#      60             loss = network.loss(output, y_placeholder)
#      61
#
# ~/project/paperEdit/haredit-ttn/network_ttn_synthetic.py in mapping(sequence, batch_size, seq_len)
#      61
#      62     # Warping layer
# ---> 63     sequence_warped = ttn.warp(tf.reshape(sequence1, [batch_size, seq_len, 1]), gamma)
#      64     sequence_warped = tf.reshape(sequence_warped, [batch_size, seq_len])
#      65
#
# ~/project/paperEdit/haredit-ttn/ttn.py in warp(poses, gamma)
#      49     offset = range_vec_tile_vec * seq_len
#      50
# ---> 51     Ia_flat = tf.gather(poses_flat, gamma_0_flat + offset)
#      52     Ib_flat = tf.gather(poses_flat, gamma_1_flat + offset)
#      53
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in gather(***failed resolving arguments***)
#    2673     return params.sparse_read(indices, name=name)
#    2674   except AttributeError:
# -> 2675     return gen_array_ops.gather_v2(params, indices, axis, name=name)
#    2676
#    2677
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/ops/gen_array_ops.py in gather_v2(params, indices, axis, name)
#    3330   if _ctx is None or not _ctx._eager_context.is_eager:
#    3331     _, _, _op = _op_def_lib._apply_op_helper(
# -> 3332         "GatherV2", params=params, indices=indices, axis=axis, name=name)
#    3333     _result = _op.outputs[:]
#    3334     _inputs_flat = _op.inputs
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     785         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     786                          input_types=input_types, attrs=attr_protos,
# --> 787                          op_def=op_def)
#     788       return output_structure, op_def.is_stateful, op
#     789
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     486                 'in a future version' if date is None else ('after %s' % date),
#     487                 instructions)
# --> 488       return func(*args, **kwargs)
#     489     return tf_decorator.make_decorator(func, new_func, 'deprecated',
#     490                                        _add_deprecated_arg_notice_to_docstring(
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(***failed resolving arguments***)
#    3272           input_types=input_types,
#    3273           original_op=self._default_original_op,
# -> 3274           op_def=op_def)
#    3275       self._create_op_helper(ret, compute_device=compute_device)
#    3276     return ret
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1742       if not all(
#    1743           x.is_compatible_with(i.dtype)
# -> 1744           for i, x in zip(inputs, input_types)):
#    1745         raise TypeError("In op '%s', input types (%s) are not compatible "
#    1746                         "with expected types (%s)" %
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in <genexpr>(.0)
#    1741     else:
#    1742       if not all(
# -> 1743           x.is_compatible_with(i.dtype)
#    1744           for i, x in zip(inputs, input_types)):
#    1745         raise TypeError("In op '%s', input types (%s) are not compatible "
#
# KeyboardInterrupt:

# %% [markdown]
# ```bash
#
# ```

# %% [markdown]
# # <a id='constrain_2'>CS_2</a>

# %%
# %%time
dict_cus["distance_int"] = 2
train_ttn(dict_cus)
# Out:
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/2/npy/3/kyoto11-train-x-0.npy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/project/paperEdit/haredit-ttn/train_network_synthetic.py in train_ttn(dict_cus)
#      30             cutdatadir,
#      31             dict_cus["seq_len"],
# ---> 32             k)
#      33
#      34         train_data = x_train
#
# ~/project/paperEdit/haredit-ttn/configuration/general.py in load_data(data_name, cutdatadir, data_lenght, k)
#      33     data_type = 'test'
#      34     data_x_path = os.path.join(cutdatadir, data_name + '-' + data_type + '-x-' + str(k) + '.npy')
# ---> 35     x_test = np.load(data_x_path, allow_pickle=True)
#      36
#      37     data_y_path = os.path.join(cutdatadir, data_name + '-' + data_type + '-y-' + str(k) + '.npy')
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438             else:
#     439                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 440                                          pickle_kwargs=pickle_kwargs)
#     441         else:
#     442             # Try a pickle
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     739         if isfileobj(fp):
#     740             # We can use the fast fromfile() function.
# --> 741             array = numpy.fromfile(fp, dtype=dtype, count=count)
#     742         else:
#     743             # This is not a real file. We have to read it the
#
# KeyboardInterrupt:

# %% [markdown]
# ```bash
#
# ```

# %% [markdown]
# # <a id='constrain_3'>CS_3</a>

# %%
# %%time
dict_cus["distance_int"] = 3
train_ttn(dict_cus)
# Out:
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/3/npy/3/kyoto11-train-x-0.npy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/project/paperEdit/haredit-ttn/train_network_synthetic.py in train_ttn(dict_cus)
#      30             cutdatadir,
#      31             dict_cus["seq_len"],
# ---> 32             k)
#      33
#      34         train_data = x_train
#
# ~/project/paperEdit/haredit-ttn/configuration/general.py in load_data(data_name, cutdatadir, data_lenght, k)
#      23     print(emoji.emojize(":check_mark_button: data_x_path: {}".format(data_x_path)))
#      24
# ---> 25     x_train = np.load(data_x_path, allow_pickle=True)
#      26
#      27     data_y_path = os.path.join(cutdatadir, data_name + '-' + data_type + '-y-' + str(k) + '.npy')
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438             else:
#     439                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 440                                          pickle_kwargs=pickle_kwargs)
#     441         else:
#     442             # Try a pickle
#
# ~/anaconda3/envs/HARedit/lib/python3.6/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     739         if isfileobj(fp):
#     740             # We can use the fast fromfile() function.
# --> 741             array = numpy.fromfile(fp, dtype=dtype, count=count)
#     742         else:
#     743             # This is not a real file. We have to read it the
#
# KeyboardInterrupt:

# %% [markdown]
# ```bash
#
# ```

# %% [markdown]
# # <a id='constrain_4'>CS_4</a>

# %%
# %%time
dict_cus["distance_int"] = 4
train_ttn(dict_cus)
# Out:
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/4/npy/3/kyoto11-train-x-0.npy
# k: 0	step: 0/212000, loss_value: 2.3989529609680176
# Create subdir directory: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/4/0...
# model saved at: ../datasets/casas/results/ttn/kyoto11/2000_32_1024/4/0/0_0_gaussians_github_ttn_2.398953
# ✅ data_x_path: ../datasets/casas/ende/kyoto11/4/npy/3/kyoto11-train-x-0.npy
# INFO:tensorflow:Restoring parameters from ../datasets/casas/results/ttn/kyoto11/2000_32_1024/4/0/0_0_gaussians_github_ttn_2.398953

# %% [markdown]
# ```bash
#
# ```

# %% [markdown]
# # <a id='constrain_5'>CS_5</a>

# %%
# %%time
dict_cus["distance_int"] = 5
train_ttn(dict_cus)

# %% [markdown]
# ```bash
#
# ```

# %% [markdown]
# # <a id='statics'>statics</a>

# %%
dict_cus["num_classes"] = 0
dict_cus["num_train"] = 0

from configuration import configure
configure.parameters_dict = general.Merge(configure.parameters_dict, dict_cus)
weights_dir = general.getWeightsDir(configure.parameters_dict, 2)
general.showResult(weights_dir)
